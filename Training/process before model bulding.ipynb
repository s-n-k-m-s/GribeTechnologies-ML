# %% [markdown]
# ## importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading dataset

# %%
#loading the apple quality dataset
df = pd.read_csv('apple_quality.csv')
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df.shape #determines the shape of the dataset
# Out:
# (4001, 9)

# %%
df.head(7) #displays first 7 rows of the dataset
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# 5   5.0 -3.425400 -1.409082  -1.913511    -0.555775  -3.853071  1.914616
# 6   6.0  1.331606  1.635956   0.875974    -1.677798   3.106344 -1.847417
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good
# 5  -2.981523169     bad
# 6   2.414170509    good

# %%
df.tail(8) #displays last 8 rows of the dataset
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 3993  3993.0  1.520142 -0.352623  -3.206467     1.341719   0.675568  0.107093
# 3994  3994.0  1.482508 -2.581181  -0.306888     1.527877   1.056361  2.560829
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 3993                       -0.945080106     bad
# 3994                       -1.229254586    good
# 3995                        0.137784369     bad
# 3996                        1.854235285    good
# ...

# %%
df.sample(10) #displays 10 rows randomly
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 592    592.0  3.200290  0.962163  -0.530071     0.746540  -1.003161  0.450423
# 1386  1386.0  0.536564 -6.000748   3.597462     3.960715   2.367717  3.028437
# 950    950.0  3.182513 -1.237397  -2.919526     1.596672  -0.688642  1.564197
# 67      67.0 -1.569764  1.059865   1.518880     1.666096   3.068931 -1.480351
# 2572  2572.0 -0.517699 -0.804642   2.329575     0.922024  -0.154364  0.759059
# 1623  1623.0  1.863797 -2.746753   0.886767     1.410066  -3.917207 -0.762653
# 2044  2044.0 -3.869671  0.548426  -2.411874    -0.338116   1.521932  2.496692
# 524    524.0 -2.067245 -0.272901  -1.110935     0.949659  -1.470450 -0.317205
# 1651  1651.0 -0.222959  0.280609   0.841970     2.277427  -0.770974 -1.621405
# 1501  1501.0  0.687982 -0.135093  -1.257287     3.237504  -1.205992 -1.335646
#
#            Acidity Quality
# 592    2.576949552    good
# 1386    2.34552157    good
# ...

# %%
df.describe() #gives description of the dataset
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness
# count  4000.000000  4000.000000
# mean      0.512118     0.498277
# std       1.930286     1.874427
# min      -5.961897    -5.864599
# 25%      -0.801286    -0.771677
# 50%       0.534219     0.503445
# 75%       1.835976     1.766212
# max       7.364403     7.237837

# %%
df.nunique() #displays no.of unique values in each and every column
# Out:
# A_id           4000
# Size           4000
# Weight         4000
# Sweetness      4000
# Crunchiness    4000
# Juiciness      4000
# Ripeness       4000
# Acidity        4001
# Quality           2
# dtype: int64

# %%
df.loc[1729] #displays the data present in the 1729th index
# Out:
# A_id                1729.0
# Size             -1.329337
# Weight            0.545297
# Sweetness        -1.162827
# Crunchiness       2.927927
# Juiciness        -1.837274
# Ripeness         -1.879259
# Acidity        0.051273904
# Quality               good
# Name: 1729, dtype: object

# %%
df.loc[[1,172,1729,12]] # for displaying multiple rows data in the indexes mentioned
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 172    172.0 -0.125752  0.024645   0.003256     1.456974  -0.178902  2.083774
# 1729  1729.0 -1.329337  0.545297  -1.162827     2.927927  -1.837274 -1.879259
# 12      12.0 -0.170812 -1.867271  -1.771845     2.413155  -3.094555 -0.624884
#
#            Acidity Quality
# 1     -0.722809367    good
# 172   -0.131763548    good
# 1729   0.051273904    good
# 12    -2.076113997     bad

# %%
df.columns #displays the column names present in the dataset
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %%
df['Acidity'].unique # unique values in that particular column will be displayed.
# Out:
# <bound method Series.unique of 0                            -0.491590483
# 1                            -0.722809367
# 2                             2.621636473
# 3                             0.790723217
# 4                             0.501984036
#                       ...
# 3996                          1.854235285
# 3997                         -1.334611391
# 3998                         -2.229719806
# 3999                          1.599796456
# 4000    Created_by_Nidula_Elgiriyewithana
# Name: Acidity, Length: 4001, dtype: object>

# %%
df.value_counts() #displays the frequency of each row in the dataset
# df['Size'].value_counts -> frequency of each row in Size column will be displayed
# Out:
# A_id    Size       Weight     Sweetness  Crunchiness  Juiciness  Ripeness   Acidity       Quality
# 0.0     -3.970049  -2.512336   5.346330  -1.012009     1.844900   0.329840  -0.491590483  good       1
# 2671.0  -3.844134  -2.729138  -0.812468   1.390671     1.839132   5.411911  1.006877454   bad        1
# 2658.0  -4.411655   2.702494  -0.708549  -2.162584    -0.664962   0.751173  -0.132407603  good       1
# 2659.0  -1.480046  -0.326744  -1.453041   0.898155     1.372992   0.762387  1.223084441   bad        1
# 2660.0   0.749942  -2.590200  -1.227472   0.322952    -1.046933  -0.030211  2.190636353   bad        1
#                                                                                                     ..
# 1338.0  -2.385353  -2.367245  -1.600530   1.851129     1.759377   1.508037  -3.873112715  bad        1
# 1339.0   0.612499  -3.353272  -0.636006   1.037675     1.838079  -1.629855  -0.08899782   good       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4001 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %%
df.isna()
# Out:
#        A_id   Size  Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0     False  False   False      False        False      False     False
# 1     False  False   False      False        False      False     False
# 2     False  False   False      False        False      False     False
# 3     False  False   False      False        False      False     False
# 4     False  False   False      False        False      False     False
# ...     ...    ...     ...        ...          ...        ...       ...
# 3996  False  False   False      False        False      False     False
# 3997  False  False   False      False        False      False     False
# 3998  False  False   False      False        False      False     False
# 3999  False  False   False      False        False      False     False
# 4000   True   True    True       True         True       True      True
#
#       Acidity  Quality
# 0       False    False
# 1       False    False
# 2       False    False
# ...

# %%
df.iloc[3:1234,4:7] # accesing those particular columns and particular rows
# Out:
#       Crunchiness  Juiciness  Ripeness
# 3       -0.097875   3.637970 -3.413761
# 4       -0.553006   3.030874 -1.303849
# 5       -0.555775  -3.853071  1.914616
# 6       -1.677798   3.106344 -1.847417
# 7       -0.742972   0.158834  0.974438
# ...           ...        ...       ...
# 1229     1.889234  -0.550327 -1.137563
# 1230     2.138904  -0.595182 -1.299815
# 1231    -0.842211  -0.801428  1.930385
# 1232     0.978989   2.205031  1.298361
# 1233     1.737929  -2.175783 -0.064183
#
# [1231 rows x 3 columns]

# %% [markdown]
# ## preprocessing

# %%
#cleaning the dataset
da = df.dropna() # removes the rows with null value
da
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# ...

# %%
da2 = df.fillna('no value') # replacing the null values with 'no value' where ever there is a null value
da2
# Out:
#           A_id      Size    Weight Sweetness Crunchiness Juiciness  Ripeness  \
# 0          0.0 -3.970049 -2.512336   5.34633   -1.012009    1.8449   0.32984
# 1          1.0 -1.195217 -2.839257  3.664059    1.588232  0.853286   0.86753
# 2          2.0 -0.292024 -1.351282 -1.738429   -0.342616  2.838636 -0.038033
# 3          3.0 -0.657196 -2.271627  1.324874   -0.097875   3.63797 -3.413761
# 4          4.0  1.364217 -1.296612 -0.384658   -0.553006  3.030874 -1.303849
# ...        ...       ...       ...       ...         ...       ...       ...
# 3996    3996.0 -0.293118  1.949253  -0.20402   -0.640196  0.024523   -1.0879
# 3997    3997.0 -2.634515 -2.138247 -2.440461    0.657223  2.199709  4.763859
# 3998    3998.0 -4.008004 -1.779337  2.366397   -0.200329  2.161435  0.214488
# 3999    3999.0   0.27854 -1.715505  0.121217   -1.154075  1.266677 -0.776571
# 4000  no value  no value  no value  no value    no value  no value  no value
#
# ...

# %%
#handling wrong data
#assuming that my 2 row is having wrong data so I am deleting that row
da3 = df.drop(2)
da3
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# 5        5.0 -3.425400 -1.409082  -1.913511    -0.555775  -3.853071  1.914616
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
#replacing the quality of the apple in 2nd row to bad
da.loc[2,'Quality'] = 'good'
da
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# ...

# %%
# checking duplicates and removing them
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3996    False
# 3997    False
# 3998    False
# 3999    False
# 4000    False
# Length: 4001, dtype: bool

# %%
da4 = df.drop_duplicates()
da4 # all the duplicates are removed
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
# label encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder() # creating an object
le
# Out:
# LabelEncoder()

# %%
df['Quality'] = le.fit_transform(df['Quality'])
df #bad - 0 good - 1
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df['Weight'].mean() #mean of the Weight column
# Out:
# -0.9895465445945

# %%
df['Sweetness'].median() # median of the Sweetness column
# Out:
# -0.5047584635

# %%
df['Juiciness'].mode() #mode of the Juiciness column
# Out:
# 0      -5.961897
# 1      -5.814308
# 2      -5.801766
# 3      -5.743512
# 4      -5.713431
#           ...
# 3995    6.328304
# 3996    6.446302
# 3997    6.497706
# 3998    7.148502
# 3999    7.364403
# Name: Juiciness, Length: 4000, dtype: float64

# %%
df['Crunchiness'].std() # standard deviation of the crunchiness column
# Out:
# 1.4027572042119607

# %%
df['Ripeness'].var() # variance of the Ripeness column
# Out:
# 3.513475737473624

# %%
df.corr(numeric_only=True) #correlation b/w the numerical columns
# Out:
#                  A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  \
# A_id         1.000000 -0.028911 -0.005730  -0.002378    -0.013111   0.006179
# Size        -0.028911  1.000000 -0.170702  -0.324680     0.169868  -0.018892
# Weight      -0.005730 -0.170702  1.000000  -0.154246    -0.095882  -0.092263
# Sweetness   -0.002378 -0.324680 -0.154246   1.000000    -0.037552   0.095882
# Crunchiness -0.013111  0.169868 -0.095882  -0.037552     1.000000  -0.259607
# Juiciness    0.006179 -0.018892 -0.092263   0.095882    -0.259607   1.000000
# Ripeness     0.000742 -0.134773 -0.243824  -0.273800    -0.201982  -0.097144
# Quality      0.004875  0.244007  0.001421   0.250998    -0.012376   0.260223
#
#              Ripeness   Quality
# A_id         0.000742  0.004875
# Size        -0.134773  0.244007
# Weight      -0.243824  0.001421
# Sweetness   -0.273800  0.250998
# Crunchiness -0.201982 -0.012376
# Juiciness   -0.097144  0.260223
# Ripeness     1.000000 -0.264315
# ...

# %% [markdown]
# ## plotting a graph

# %%
# How many bad apples and Good apples are present 
plt.bar(df['Quality'],df['A_id'])
plt.xlabel('Quality')
plt.ylabel('apple id')
plt.title('No of good and bad apples in the dataset')
plt.show()

# %% [markdown]
# ## train_test split

# %%
df.dropna(inplace=True) # removes the null value rows permanently
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity  Quality
# ...

# %%
df.columns
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
#input variables
x = df[['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
       'Ripeness', 'Acidity']]
#output variables
y = df['Quality']
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=42)
print('shape of x_train: ',x_train.shape)
print('shape of x_test: ',x_test.shape)
print('shape of y_train: ',y_train.shape)
print('shape of y_test: ',y_test.shape)
# Out:
# shape of x_train:  (2680, 7)
# shape of x_test:  (1320, 7)
# shape of y_train:  (2680,)
# shape of y_test:  (1320,)
