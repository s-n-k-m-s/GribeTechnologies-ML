# %% [markdown]
# ### 1) Importing required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# importing required packages

# %% [markdown]
# ### 2) Loading laptopPrice dataset

# %%
df = pd.read_csv("laptopPrice.csv") #to load the csv file we use read_csv
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
# performing few operations on dataset
df.head(9) # displays first 9 rows
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 7    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 8  Lenovo           Intel        Core i5            10th   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# ...

# %%
df.tail(7) #displays last 7 rows
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 816    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 817    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 816  1024 GB  0 GB  Windows  32-bit            6 GB      Casual  No warranty
# 817  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 818  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# ...

# %%
df.sample(8) # displays 8 random rows
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 795  Lenovo             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 234     MSI           Intel        Core i5            10th   8 GB     DDR4
# 208    ASUS           Intel        Core i5            11th   8 GB     DDR4
# 609   APPLE              M1             M1            10th   8 GB     DDR4
# 19   Lenovo           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 100      HP           Intel        Core i3            11th   8 GB     DDR4
# 628    acer           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 511     MSI           Intel        Core i7            11th  16 GB     DDR4
#
#         ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 795  512 GB  1024 GB  Windows  32-bit            0 GB      Casual
# 234  512 GB     0 GB  Windows  64-bit            4 GB      Casual
# 208  256 GB     0 GB  Windows  64-bit            0 GB  ThinNlight
# ...

# %%
df.shape # defines the dataset size
# Out:
# (823, 19)

# %%
df.nunique() #displays no.of unique values in each and every column
# Out:
# brand                  8
# processor_brand        3
# processor_name        11
# processor_gnrtn        8
# ram_gb                 4
# ram_type               6
# ssd                    7
# hdd                    4
# os                     3
# os_bit                 2
# graphic_card_gb        5
# weight                 3
# warranty               4
# Touchscreen            2
# msoffice               2
# Price                405
# rating                 5
# Number of Ratings    282
# Number of Reviews    135
# dtype: int64

# %%
df.describe() 
# gives description by performing all the mathematical functions on numerical data
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
df.info() # gives information about the datset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.iloc[67:230,2:6] # accessing particular rows and columns
# Out:
#     processor_name processor_gnrtn ram_gb ram_type
# 67         Core i3            10th   4 GB     DDR4
# 68         Core i3            11th   4 GB     DDR4
# 69         Core i3            10th   4 GB     DDR4
# 70         Core i3            10th   4 GB     DDR4
# 71         Core i3            11th   4 GB     DDR4
# ..             ...             ...    ...      ...
# 225        Core i5            11th   8 GB     DDR4
# 226        Core i5            11th   8 GB     DDR4
# 227        Core i5            10th   8 GB     DDR4
# 228        Core i5            11th   8 GB     DDR4
# 229        Core i5            10th   8 GB     DDR4
#
# [163 rows x 4 columns]

# %%
df.isna() # identifies whether are there any null values in the dataset
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0    False            False           False            False   False
# 1    False            False           False            False   False
# 2    False            False           False            False   False
# 3    False            False           False            False   False
# 4    False            False           False            False   False
# ..     ...              ...             ...              ...     ...
# 818  False            False           False            False   False
# 819  False            False           False            False   False
# 820  False            False           False            False   False
# 821  False            False           False            False   False
# 822  False            False           False            False   False
#
#      ram_type    ssd    hdd     os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %% [markdown]
# ### 3) Data preprocessing

# %%
df.isna().sum() #sum of null values present in each column
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
# there are no wrong data and no null values
df.duplicated() #checks whether there are any duplicates present in the dataset
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
df.duplicated().sum() # gives the sum value of no.of duplicates in dataset
# Out:
# 21

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.shape
# Out:
# (802, 19)

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder() # object created

# %%
df.columns # displays all columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
# converting categorical values to numerical values
c = (['brand','processor_brand', 'processor_name', 'processor_gnrtn',
       'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
       'weight', 'warranty', 'Touchscreen', 'msoffice','rating'])
for i in c:
    df[i] = le.fit_transform(df[i])

df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                0       2
# 1        5                1               1                0       2
# 2        5                1               1                0       2
# 3        1                1               2                0       3
# 4        1                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      1                0              10                7       2
# 819      1                0              10                7       2
# 820      1                0              10                7       2
# 821      1                0              10                7       2
# 822      5                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
# feture selection -> selecting input and output variables
x = df[['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
       'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
       'weight', 'warranty', 'Touchscreen', 'msoffice', 'rating',
       'Number of Ratings', 'Number of Reviews']] #input features
y = df['Price']

# %% [markdown]
# ### 4) Splitting dataset into training and testing data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=42)
#test data -> 33% train data-> 67%
print('shape of x_train: ',x_train.shape)
print('shape of x_test: ',x_test.shape)
print('shape of y_train: ',y_train.shape)
print('shape of y_test: ',y_test.shape)
# Out:
# shape of x_train:  (537, 18)
# shape of x_test:  (265, 18)
# shape of y_train:  (537,)
# shape of y_test:  (265,)

# %% [markdown]
# ### 5) model building

# %%
#importing the model
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %% [markdown]
# ### 6) Model training

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 7) testing the model

# %%
y_pred = lr.predict(x_test) # for predicting the values
y_pred
# Out:
# array([-12611.4838665 ,  67517.41148769,  31311.68023073, 136540.45439609,
#        151424.97876641, 151276.45074099, 107354.23143522,  47780.29190193,
#         49389.06453322,  49224.0001561 ,  60929.81077772,  46297.76949358,
#         83552.92860036,  90157.12793715,  61801.71154416, 133636.39602647,
#         79229.53692163,  49409.00597544,  62631.70888925, 146003.31683741,
#         48476.66791871,  59309.54519238,  71806.81140374,  76469.53321353,
#         52050.53890582,  56741.23698069,  77598.25387634, 157280.03747661,
#         56917.75369338,  63191.33844207,  42514.7904873 ,  49288.19540623,
#         36747.55475433,  58027.15604056,  59716.30608381,  58390.03315828,
#        156381.44051151,  68045.06850127,  77469.7129863 ,  69084.93456229,
#         49555.54759062,  71757.94604816,  45680.93879818,  52692.67112372,
#        156249.87226531,  65196.19816085, 120639.82443007,  71312.82351007,
# ...

# %% [markdown]
# ### 8) Evaluation Metrics

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
mse = mean_squared_error(y_test, y_pred) #mean Square error
mae = mean_absolute_error(y_test, y_pred) # mean absolute error
r2 = r2_score(y_test, y_pred) #r2 score

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 1082141258.693408
# Mean Absolute Error: 18334.135701655745
# R-squared: 0.5414210699272114

# %% [markdown]
# ### 9) predicting unseen data

# %%
s = np.array([5,1,1,0,2,1,0,1,2,1,0,0,3,0,0,2,65,5])
s = s.reshape(1,18)

# %%
output = lr.predict(s)
print(output[0])
# Out:
# 57967.0474455408
# C:\Users\KRISHNA MOHAN\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### plotting graphs

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("actual test data")
plt.ylabel("predicted data")
plt.show()

# %%
#plotting a bar graph for price of each brand approximately
plt.bar(ds['brand'],ds['Price'])
plt.xlabel('Brands')
plt.ylabel('prices')
plt.show()

# %%
#plotting a pie chart to show no.of processors are present in the dataset
plt.pie(ds['processor_name'].value_counts(),labels=ds['processor_name'].value_counts().index,autopct='%.0f%%')
plt.show()

# %%
#plotting a graph for counting the ram_gb 
plt.hist(ds['ram_gb'],bins=7)
plt.title("count")
plt.show()
